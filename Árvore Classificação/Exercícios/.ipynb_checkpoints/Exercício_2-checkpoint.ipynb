# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('df.csv')
df = df.drop(columns=['Unnamed: 0'])
df.idade = df.idade.astype('int64')
df.head()
# Out:
#    sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  idade  tempo_emprego  \
# 0     0                 1                1           0     58       3.106849
# 1     1                 0                1           0     52       8.358904
# 2     0                 1                1           0     46       2.106849
# 3     1                 1                0           0     29       3.021918
# 4     1                 0                1           0     27       4.024658
#
#    possui_celular  possui_fone_comercial  possui_fone  possui_email  ...  \
# 0               1                      0            0             0  ...
# 1               1                      0            1             1  ...
# 2               1                      1            1             1  ...
# 3               1                      0            0             0  ...
# 4               1                      0            1             0  ...
#
#    estado_civil_Married  estado_civil_Separated  \
# ...

# %% [markdown]
# # Módulo 07 - Tarefa 02
#
# #### 1) Carregue a base e garanta que a base está como deveria.
#
# Considere a base que você ajustou na lição passada. Carregue-a. Caso ainda haja alguma pendência, ajuste - lembre-se de que o scikitlearn não recebe variáveis em formato string, somente numéricas, e não aceita '*missings*'.
#
# - Separe 70% da base para treinamento e 30% para validação. Cada uma dessas partes terá dois objetos, um armazenando a variável resposta ```mau```e outro armazenando as variáveis explicativas (lembrando: sem variáveis string, já com as dummies).

# %%
y = df.mau
X = df.drop(columns=['mau'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %% [markdown]
# #### 2) Vamos para o modelo:
#
# 1. Defina um objeto com a função da árvore de decisão vista em aula.
# 2. Treine o modelo com os dados que você separou para treinamento.
# 3. Visualize a árvore. Talvez você queira aumentar um pouco a figura.
# 4. Produza uma visualização da matriz de classificação (ou matriz de confusão) - coloque os rótulos como "aprovados" e "reprovados" - pois afinal de contas, são essas as decisões que se podem tomar com propostas de crédito.
# 5. Calcule a acurácia na base de treinamento

# %% [markdown]
# * Criando instância da árvore de decisão de classificação;
# * Utilizando dados de treino para treinamento.

# %%
clf = DecisionTreeClassifier(random_state=100)
clf = clf.fit(X_train,y_train)

# %% [markdown]
# * Plotagem da árvore:

# %%
plt.figure(figsize=(25, 10))
plot_tree(clf,
          filled=True,
          class_names=['Bom', 'Mau'],
          feature_names=X.columns.tolist())
# Out:
# [Text(0.6301242457599479, 0.9807692307692307, 'tempo_emprego <= 4.955\ngini = 0.085\nsamples = 4739\nvalue = [4528, 211]\nclass = Bom'),
#  Text(0.36606123613829095, 0.9423076923076923, 'tempo_emprego <= 4.949\ngini = 0.099\nsamples = 2594\nvalue = [2458, 136]\nclass = Bom'),
#  Text(0.36345197325505546, 0.9038461538461539, 'posse_de_imovel <= 0.5\ngini = 0.099\nsamples = 2592\nvalue = [2457, 135]\nclass = Bom'),
#  Text(0.2317861219830398, 0.8653846153846154, 'estado_civil_Widow <= 0.5\ngini = 0.128\nsamples = 815\nvalue = [759, 56]\nclass = Bom'),
#  Text(0.20786448140900196, 0.8269230769230769, 'tempo_emprego <= 4.647\ngini = 0.117\nsamples = 770\nvalue = [722, 48]\nclass = Bom'),
#  Text(0.18741846053489888, 0.7884615384615384, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.108\nsamples = 733\nvalue = [691, 42]\nclass = Bom'),
#  Text(0.16479125896934116, 0.75, 'tipo_residencia_Office apartment <= 0.5\ngini = 0.099\nsamples = 688\nvalue = [652, 36]\nclass = Bom'),
# ...

# %% [markdown]
# * Calculando o `predict`:

# %%
predict_train = clf.predict(X_train)

# %% [markdown]
# * Matriz de confusão base de treinamento:

# %%
cm = confusion_matrix(y_train, predict_train)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

disp.plot()
plt.show()

# %% [markdown]
# * Acurácia base de treinamento:

# %%
print(f'Acurácia base de treinamento: {accuracy_score(y_train, predict_train)}')
# Out:
# Acurácia base de treinamento: 0.9833298164169656

# %% [markdown]
# #### 3) Vamos avaliar o modelo na base de testes
#
# 1. Classifique a base de teste de acordo com a árvore que você treinou no item 2.
# 2. Produza a visualização da matriz de confusão para a base de teste.
# 3. Calcule a acurácia da base de teste. Compare com a acurácia da base de treinamento.
# 4. Treine uma nova árvore com número mínimo de observações por folha de 5 e máximo de profundidade de 10. Use o random_state = 123. Avalie a matriz de classificação. Observe a distribuição da predição - qual a proporção de proponentes foram classificados como 'maus'?
# 5. Como ficaria a acurácia se você classificasse todos os contratos como 'bons'?

# %%
predict = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

disp.plot()
plt.show()

# %% [markdown]
# * Acurácia base de testes:

# %%
print(f'Acurácia base de testes: {accuracy_score(y_test, predict)}')
# Out:
# Acurácia base de testes: 0.9177744953225012

# %% [markdown]
# * Pre-Prunning:

# %%
clf = DecisionTreeClassifier(min_samples_leaf=5, max_depth=10, random_state=123)
clf = clf.fit(X_train,y_train)

# %% [markdown]
# * Plotagem da árvore:

# %%
plt.figure(figsize=(25, 10))
plot_tree(clf,
          filled=True,
          class_names=['Bom', 'Mau'],
          feature_names=X.columns.tolist())
# Out:
# [Text(0.5718219647519582, 0.9545454545454546, 'tempo_emprego <= 4.955\ngini = 0.085\nsamples = 4739\nvalue = [4528, 211]\nclass = Bom'),
#  Text(0.287532637075718, 0.8636363636363636, 'posse_de_imovel <= 0.5\ngini = 0.099\nsamples = 2594\nvalue = [2458, 136]\nclass = Bom'),
#  Text(0.14768276762402088, 0.7727272727272727, 'estado_civil_Widow <= 0.5\ngini = 0.13\nsamples = 817\nvalue = [760, 57]\nclass = Bom'),
#  Text(0.1152088772845953, 0.6818181818181818, 'tempo_emprego <= 4.647\ngini = 0.119\nsamples = 772\nvalue = [723, 49]\nclass = Bom'),
#  Text(0.08942558746736293, 0.5909090909090909, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.108\nsamples = 733\nvalue = [691, 42]\nclass = Bom'),
#  Text(0.06919060052219321, 0.5, 'tipo_residencia_Office apartment <= 0.5\ngini = 0.099\nsamples = 688\nvalue = [652, 36]\nclass = Bom'),
#  Text(0.0639686684073107, 0.4090909090909091, 'tempo_emprego <= 3.816\ngini = 0.095\nsamples = 679\nvalue = [645, 34]\nclass = Bom'),
# ...

# %% [markdown]
# * Calculando o `predict`:

# %%
predict = clf.predict(X_test)
predict_train = clf.predict(X_train)

# %% [markdown]
# * Matriz de confusão:

# %%
cm = confusion_matrix(y_test, predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

disp.plot()
plt.show()

# %% [markdown]
# * Acurácia para base de testes:

# %%
print(f'Acurácia base de testes: {accuracy_score(y_test, predict)}')
# Out:
# Acurácia base de testes: 0.9547021171836534

# %%
cm = confusion_matrix(y_train, predict_train)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

disp.plot()
plt.show()

# %%
print(f'Acurácia base de treinamento: {accuracy_score(y_train, predict_train)}')
# Out:
# Acurácia base de treinamento: 0.9561088837307449
